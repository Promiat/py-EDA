# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
nobel_data = pd.read_csv('./DATA/nobel_prize_by_winner.csv', encoding="ISO-8859-1")

# %%
nobel_data.describe()
# Out:
#                id         year       share
# count  972.000000   966.000000  966.000000
# mean   471.365226  1970.145963    2.005176
# std    275.012711    32.889742    0.930193
# min      1.000000  1901.000000    1.000000
# 25%    230.750000  1947.000000    1.000000
# 50%    463.500000  1976.000000    2.000000
# 75%    720.250000  1999.000000    3.000000
# max    934.000000  2016.000000    4.000000

# %%
nobel_data.head()
# Out:
#     id         firstname  surname        born        died bornCountry  \
# 0  846            Elinor   Ostrom    8/7/1933   6/12/2012         USA
# 1  846            Elinor   Ostrom    8/7/1933   6/12/2012         USA
# 2  783      Wangari Muta  Maathai    4/1/1940   9/25/2011       Kenya
# 3  230  Dorothy Crowfoot  Hodgkin   5/12/1910   7/29/1994       Egypt
# 4  918            Youyou       Tu  12/30/1930  0000-00-00       China
#
#   bornCountryCode         bornCity     diedCountry diedCountryCode  \
# 0              US  Los Angeles, CA             USA              US
# 1              US  Los Angeles, CA             USA              US
# 2              KE            Nyeri           Kenya              KE
# 3              EG            Cairo  United Kingdom              GB
# 4              CN  Zhejiang Ningbo             NaN             NaN
#
#             diedCity  gender    year   category overallMotivation  share  \
# ...

# %%
sns.relplot(x="bornCountry",y="gender",data=nobel_data)
